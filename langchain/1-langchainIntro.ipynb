# %%
import langchain
langchain.__version__
# Out:
# '1.4.0'

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

def get_weather (city : str)-> str:
    """ get the weather of the city."""
    return f"The weather in the {city} is sunny"

agent = ChatGroq(
    model= "openai/gpt-oss-20b",
    tools=[get_weather],
    system_prompt="Yor are helpful"
)
agent
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0'}}, profile={'name': 'GPT OSS 20B', 'release_date': '2025-08-05', 'last_updated': '2026-05-27', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x00000237F0D3FD30>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000237F0CD3BB0>, model_name='openai/gpt-oss-20b', model_kwargs={'tools': [<function get_weather at 0x00000237F0C4FA30>], 'system_prompt': 'Yor are helpful'}, groq_api_key=SecretStr('**********'))

# %%
# 1. Pass 'messages' (plural)
response = agent.invoke({
    "messages": [{"role": "user", "content": "what is capital of india"}]
})

# 2. Extract the text from the last message
print(response["messages"][-1].content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 1. Pass 'messages' (plural)
# ----> 2 response = agent.invoke({
#       3     "messages": [{"role": "user", "content": "what is capital of india"}]
#       4 })
#       6 # 2. Extract the text from the last message
#       7 print(response["messages"][-1].content)
#
# File c:\Users\coder\OneDrive\Desktop\New folder\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:489, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)
#     481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
#     488             self.generate_prompt(
# ...

# %%
response = agent.invoke("what is capital of india")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 response = agent.invoke("what is capital of india")
#       2 print(response.content)
#
# File c:\Users\coder\OneDrive\Desktop\New folder\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)
#     481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
# ...
